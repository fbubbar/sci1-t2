# %%
import sys
sys.path.append('..')

from analyse.prelude import *

# %%
trials, meta = load_files('round1')
plot_trials_w(trials, meta)
# Out:
# [INFO] Processing '../data/round1/Gyroscope rotation rate 2025-01-16 17-03-03/Raw Data.csv' ...
# [INFO] Processing '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11/Raw Data.csv' ...
# [INFO] -> discarding segment 0
# [INFO] Found 7 trials in 2 files.
# [INFO] Trial 1: source '../data/round1/Gyroscope rotation rate 2025-01-16 17-03-03' #0
# [INFO] Comment: Intermediate axis rotation
# [INFO] Trial 2: source '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11' #1
# [INFO] Comment: Intermediate axis rotation
# [INFO] Trial 3: source '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11' #2
# [INFO] Comment: Tertiary axis rotation
# [INFO] Trial 4: source '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11' #3
# [INFO] Comment: Primary axis rotation
# [INFO] Trial 5: source '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11' #4
# [INFO] Comment: Tertiary axis rotation
# [INFO] Trial 6: source '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11' #5
# [INFO] Comment: Intermediate axis rotation
# [INFO] Trial 7: source '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11' #6
# [INFO] Comment: Fast intermediate axis rotation

# %%
I = box_moi(*PHONE_DIMS, PHONE_MASS)

for trial in trials:
    add_angular_momentum(trial, I)

plot_trials_L(trials, meta)
# Out:
# [INFO] Trial 1: source '../data/round1/Gyroscope rotation rate 2025-01-16 17-03-03' #0
# [INFO] Comment: Intermediate axis rotation
# [INFO] Trial 2: source '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11' #1
# [INFO] Comment: Intermediate axis rotation
# [INFO] Trial 3: source '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11' #2
# [INFO] Comment: Tertiary axis rotation
# [INFO] Trial 4: source '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11' #3
# [INFO] Comment: Primary axis rotation
# [INFO] Trial 5: source '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11' #4
# [INFO] Comment: Tertiary axis rotation
# [INFO] Trial 6: source '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11' #5
# [INFO] Comment: Intermediate axis rotation
# [INFO] Trial 7: source '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11' #6
# [INFO] Comment: Fast intermediate axis rotation

# %%
analyse_trial_freqs(trials, meta)
# Out:
# Results for segment 0 of ../data/round1/Gyroscope rotation rate 2025-01-16 17-03-03:
# -> dominant frequency: 2.04 Hz
# -> period: 0.4900 seconds
# -> peak-to-noise ratio: 16.46
#
#
# Results for segment 1 of ../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11:
# -> dominant frequency: 1.01 Hz
# -> period: 0.9900 seconds
# -> peak-to-noise ratio: 45.43
#
# [INFO] Skipping segment 2 of '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11' ...
# [INFO] Skipping segment 3 of '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11' ...
# [INFO] Skipping segment 4 of '../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11' ...
#
# Results for segment 5 of ../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11:
# -> dominant frequency: 0.88 Hz
# -> period: 1.1400 seconds
# -> peak-to-noise ratio: 123.06
#
#
# Results for segment 6 of ../data/round1/Gyroscope rotation rate 2025-01-16 17-10-11:
# -> dominant frequency: 2.78 Hz
# -> period: 0.3600 seconds
# -> peak-to-noise ratio: 13.45
