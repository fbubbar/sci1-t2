# %%
import sys
sys.path.append('..')

from analyse.prelude import *

config['save_figures'] = True

# %%
trials, meta = load_files('round3')

for trial in trials:
    add_angular_momentum(trial, PRQ_I)

i = 10
n = 10
plot_trials_w(trials[i:i+n], meta[i:i+n], manual_is=range(i,i+n))
# Out:
# [INFO] Processing '../data/round3/Gyroscope rotation rate 2025-02-14 09-35-02/Raw Data.csv' ...
# [INFO] Processing '../data/round3/Gyroscope rotation rate 2025-02-14 10-47-18/Raw Data.csv' ...
# [INFO] -> discarding segment 28
# [INFO] Found 57 trials in 2 files.
# [INFO] Trial 11: source '../data/round3/Gyroscope rotation rate 2025-02-14 09-35-02' #10
# [INFO] Comment: Intermediate axis rotation
# [INFO] Figure saved to '../figures/trial_11_17416524006.svg'
# [INFO] Trial 12: source '../data/round3/Gyroscope rotation rate 2025-02-14 09-35-02' #11
# [INFO] Comment: Intermediate axis rotation
# [INFO] Figure saved to '../figures/trial_12_17416524008.svg'
# [INFO] Trial 13: source '../data/round3/Gyroscope rotation rate 2025-02-14 09-35-02' #12
# [INFO] Comment: Intermediate axis rotation
# [INFO] Figure saved to '../figures/trial_13_17416524010.svg'
# [INFO] Trial 14: source '../data/round3/Gyroscope rotation rate 2025-02-14 09-35-02' #13
# [INFO] Comment: Intermediate axis rotation
# ...
