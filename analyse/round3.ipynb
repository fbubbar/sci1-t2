# %%
import sys
sys.path.append('..')

from analyse.prelude import *

# %%
trials, meta = load_files('round3')
plot_trials_w(trials[19:25], meta[19:25])
# Out:
# [INFO] Processing '../data/round3/Gyroscope rotation rate 2025-02-14 09-35-02/Raw Data.csv' ...
# [INFO] Processing '../data/round3/Gyroscope rotation rate 2025-02-14 10-47-18/Raw Data.csv' ...
# [INFO] Found 58 trials in 2 files.
# [INFO] Trial 1: source '../data/round3/Gyroscope rotation rate 2025-02-14 09-35-02' #19
# [INFO] Trial 2: source '../data/round3/Gyroscope rotation rate 2025-02-14 09-35-02' #20
# [INFO] Trial 3: source '../data/round3/Gyroscope rotation rate 2025-02-14 09-35-02' #21
# [INFO] Trial 4: source '../data/round3/Gyroscope rotation rate 2025-02-14 09-35-02' #22
# [INFO] Trial 5: source '../data/round3/Gyroscope rotation rate 2025-02-14 09-35-02' #23
# [INFO] Trial 6: source '../data/round3/Gyroscope rotation rate 2025-02-14 09-35-02' #24

# %%
# I = box_moi(*PHONE_DIMS, PHONE_MASS)

# for trial in trials:
#     add_angular_momentum(trial, I)

# plot_trials_L(trials, meta)

# %%
# analyse_trial_freqs(trials, meta)
