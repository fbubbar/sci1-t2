# %%
import sys
sys.path.append('..')

from analyse.prelude import *

# %%
trials, meta = load_files('round4')

# middle index to break into two parts
mi = len(trials) // 2

# plot the first half
# plot_trials_w(trials[:mi], meta[:mi])
# Out:
# [INFO] Processing '../data/round4/Gyroscope rotation rate 2025-02-23 13-16-45/Raw Data.csv' ...
# [INFO] -> discarding segment 5
# [INFO] Processing '../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34/Raw Data.csv' ...
# [INFO] -> discarding segment 1
# [INFO] -> discarding segment 2
# [INFO] -> discarding segment 3
# [INFO] -> discarding segment 4
# [INFO] -> discarding segment 5
# [INFO] -> discarding segment 6
# [INFO] -> discarding segment 10
# [INFO] -> discarding segment 40
# [INFO] Found 51 trials in 2 files.

# %%
# plot the second half
# plot_trials_w(trials[mi:], meta[mi:])

# %%
I = box_moi(*PHONE_DIMS, PHONE_MASS)

for trial in trials:
    add_angular_momentum(trial, I)

# first half
# plot_trials_L(trials[:mi], meta[:mi])

# %%
# second half
# plot_trials_L(trials[mi:], meta[mi:])

# %%
period_data = point_trial_periods(trials, meta, plot_points=True)
# Out:
# Results for segment 0 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-16-45:
# -> initial angular speed: 11.55 rad/s
# -> period: 0.7662 ± 0.0273 seconds (rel. 3.56%)
# Results for segment 1 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-16-45:
# -> initial angular speed: 8.35 rad/s
# -> period: 1.1422 ± 0.0509 seconds (rel. 4.46%)
# Results for segment 2 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-16-45:
# -> initial angular speed: 9.66 rad/s
# -> period: 1.0171 ± inf seconds (rel. inf%)
# Results for segment 3 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-16-45:
# -> initial angular speed: 10.59 rad/s
# -> period: 1.0487 ± 0.0504 seconds (rel. 4.81%)
# Results for segment 4 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-16-45:
# -> initial angular speed: 16.48 rad/s
# -> period: 0.6483 ± inf seconds (rel. inf%)
# Results for segment 6 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-16-45:
# -> initial angular speed: 13.75 rad/s
# -> period: 0.8409 ± 0.0662 seconds (rel. 7.88%)
# Results for segment 0 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 11.38 rad/s
# -> period: 0.9786 ± inf seconds (rel. inf%)
# Results for segment 7 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 18.71 rad/s
# -> period: 0.7154 ± 0.0970 seconds (rel. 13.56%)
# Results for segment 8 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 20.78 rad/s
# -> period: 0.6641 ± 0.1031 seconds (rel. 15.53%)
# Results for segment 9 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 22.27 rad/s
# -> period: 0.8430 ± 0.2674 seconds (rel. 31.72%)
# Results for segment 11 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 20.76 rad/s
# -> period: 0.6094 ± 0.0643 seconds (rel. 10.55%)
# Results for segment 12 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 21.23 rad/s
# -> period: 0.5176 ± 0.0384 seconds (rel. 7.42%)
# Results for segment 13 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 20.28 rad/s
# -> period: 0.4823 ± 0.0148 seconds (rel. 3.07%)
# Results for segment 14 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 20.35 rad/s
# -> period: 0.6507 ± 0.0739 seconds (rel. 11.35%)
# Results for segment 15 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 18.47 rad/s
# -> period: 0.5762 ± inf seconds (rel. inf%)
# Results for segment 16 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 20.30 rad/s
# -> period: 0.5278 ± 0.0355 seconds (rel. 6.72%)
# Results for segment 17 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 18.18 rad/s
# -> period: 0.5398 ± 0.0391 seconds (rel. 7.25%)
# Results for segment 18 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 14.46 rad/s
# -> period: 0.8633 ± 0.0872 seconds (rel. 10.10%)
# Results for segment 19 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 16.81 rad/s
# -> period: 0.7594 ± 0.0838 seconds (rel. 11.04%)
# Results for segment 20 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 11.88 rad/s
# -> period: 0.6401 ± 0.0255 seconds (rel. 3.98%)
# Results for segment 21 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 13.55 rad/s
# -> period: 0.6488 ± 0.0495 seconds (rel. 7.64%)
# Results for segment 22 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 16.95 rad/s
# -> period: 0.6106 ± 0.0701 seconds (rel. 11.48%)
# Results for segment 23 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 14.43 rad/s
# -> period: 0.7149 ± 0.0596 seconds (rel. 8.34%)
# Results for segment 24 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 15.15 rad/s
# -> period: 0.7441 ± 0.0803 seconds (rel. 10.79%)
# Results for segment 25 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 13.27 rad/s
# -> period: 1.0368 ± 0.1234 seconds (rel. 11.90%)
# Results for segment 26 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 13.98 rad/s
# -> period: 1.0491 ± 0.1864 seconds (rel. 17.77%)
# Results for segment 27 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 17.16 rad/s
# -> period: 0.5682 ± 0.0324 seconds (rel. 5.70%)
# Results for segment 28 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 14.72 rad/s
# -> period: 0.6048 ± 0.0387 seconds (rel. 6.39%)
# Results for segment 29 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 16.19 rad/s
# -> period: 0.7138 ± 0.0682 seconds (rel. 9.56%)
# Results for segment 30 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 15.92 rad/s
# -> period: 0.6885 ± 0.0376 seconds (rel. 5.46%)
# Results for segment 31 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 14.13 rad/s
# -> period: 0.7632 ± 0.0385 seconds (rel. 5.04%)
# Results for segment 32 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 15.48 rad/s
# -> period: 0.6368 ± 0.0423 seconds (rel. 6.64%)
# Results for segment 33 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 16.84 rad/s
# -> period: 0.6981 ± 0.0453 seconds (rel. 6.49%)
# Results for segment 34 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 16.05 rad/s
# -> period: 0.6816 ± 0.0498 seconds (rel. 7.31%)
# Results for segment 35 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 14.45 rad/s
# -> period: 0.7771 ± 0.0716 seconds (rel. 9.21%)
# Results for segment 36 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 15.96 rad/s
# -> period: 0.7199 ± 0.0899 seconds (rel. 12.49%)
# Results for segment 37 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 11.83 rad/s
# -> period: 1.1683 ± 0.1758 seconds (rel. 15.04%)
# Results for segment 38 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 14.12 rad/s
# -> period: 0.9168 ± 0.0847 seconds (rel. 9.24%)
# Results for segment 39 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 19.26 rad/s
# -> period: 0.6048 ± 0.0324 seconds (rel. 5.35%)
# Results for segment 41 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 19.87 rad/s
# -> period: 0.6603 ± 0.0926 seconds (rel. 14.02%)
# Results for segment 42 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 17.76 rad/s
# -> period: 0.6765 ± 0.0897 seconds (rel. 13.26%)
# Results for segment 43 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 18.15 rad/s
# -> period: 0.6721 ± 0.0441 seconds (rel. 6.55%)
# Results for segment 44 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 17.34 rad/s
# -> period: 0.6416 ± 0.0653 seconds (rel. 10.18%)
# Results for segment 45 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 17.02 rad/s
# -> period: 0.9421 ± 0.1712 seconds (rel. 18.18%)
# Results for segment 46 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 16.75 rad/s
# -> period: 0.7560 ± inf seconds (rel. inf%)
# Results for segment 47 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 13.62 rad/s
# -> period: 0.8863 ± 0.0584 seconds (rel. 6.59%)
# Results for segment 48 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 15.17 rad/s
# -> period: 0.8845 ± 0.1730 seconds (rel. 19.57%)
# Results for segment 49 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 15.29 rad/s
# -> period: 0.8262 ± inf seconds (rel. inf%)
# Results for segment 50 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 16.39 rad/s
# -> period: 0.6855 ± 0.0454 seconds (rel. 6.62%)
# Results for segment 51 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 15.56 rad/s
# -> period: 0.7778 ± 0.0499 seconds (rel. 6.41%)
# Results for segment 52 of ../data/round4/Gyroscope rotation rate 2025-02-23 13-28-34:
# -> initial angular speed: 16.24 rad/s
# -> period: 0.7538 ± 0.0902 seconds (rel. 11.97%)

# %%
plot_speed_vs_period(period_data)
